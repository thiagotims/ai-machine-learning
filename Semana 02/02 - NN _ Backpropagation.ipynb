# %% [markdown]
# <img src="https://raw.githubusercontent.com/alan-barzilay/NLPortugues/master/imagens/logo_nlportugues.png"   width="150" align="right">
#
#
# # Lista 2 - NN & Backpropagation

# %% [markdown]
# Lista de Exercicios 2 - Curso NLP (USP)
# - notes: básico em redes neurais.

# %% [markdown]
# _________________________________________
#
# Antes de começar o exercício,  não se esqueça de instalar todos os pacotes necessários para a sua execução.

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras
from sklearn.model_selection import train_test_split
# %matplotlib inline
tf.__version__
# Out:
# '2.17.1'

# %% [markdown]
# ## Perceptron
#
# O perceptron é uma "rede neural" de um só neurônio.  No nosso caso, temos a rede mais simples possível, com uma só entrada e uma só saída, sem ativação.
#
# Temos 100 dados que serão usados para treinar 300 épocas do percéptron.
#
# Vamos utilizar o modelo percéptron para aprender uma simples regressão linear, o objetivo é faze-lo aprender uma simples equação linear e tambem se acostumar com a sintaxe e funcionamento do TensorFlow

# %%
def f1(x):
    '''
    Funcao a ser aprendida
    '''
    return 5 + 10*x

# %%
xs = np.linspace(0,10,100)  # gera 100 valores no intervalo [0.10]
ys = f1(xs)                 # computa o valor de f1 nestes 100 valores
print(len(xs), "xs=", xs)
print(len(ys), "ys=", ys)
# Out:
# 100 xs= [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
#   7.87878788  7.97979798  8.08080808  8.18181818  8.28282828  8.38383838
#   8.48484848  8.58585859  8.68686869  8.78787879  8.88888889  8.98989899
#   9.09090909  9.19191919  9.29292929  9.39393939  9.49494949  9.5959596
#   9.6969697   9.7979798   9.8989899  10.        ]
# 100 ys= [  5.           6.01010101   7.02020202   8.03030303   9.04040404
#   10.05050505  11.06060606  12.07070707  13.08080808  14.09090909
#   15.1010101   16.11111111  17.12121212  18.13131313  19.14141414
#   20.15151515  21.16161616  22.17171717  23.18181818  24.19191919
#   25.2020202   26.21212121  27.22222222  28.23232323  29.24242424
#   30.25252525  31.26262626  32.27272727  33.28282828  34.29292929
#   35.3030303   36.31313131  37.32323232  38.33333333  39.34343434
#   40.35353535  41.36363636  42.37373737  43.38383838  44.39393939
#   45.4040404   46.41414141  47.42424242  48.43434343  49.44444444
#   50.45454545  51.46464646  52.47474747  53.48484848  54.49494949
#   55.50505051  56.51515152  57.52525253  58.53535354  59.54545455
#   60.55555556  61.56565657  62.57575758  63.58585859  64.5959596
#   65.60606061  66.61616162  67.62626263  68.63636364  69.64646465
#   70.65656566  71.66666667  72.67676768  73.68686869  74.6969697
#   75.70707071  76.71717172  77.72727273  78.73737374  79.74747475
#   80.75757576  81.76767677  82.77777778  83.78787879  84.7979798
#   85.80808081  86.81818182  87.82828283  88.83838384  89.84848485
#   90.85858586  91.86868687  92.87878788  93.88888889  94.8989899
#   95.90909091  96.91919192  97.92929293  98.93939394  99.94949495
#  100.95959596 101.96969697 102.97979798 103.98989899 105.        ]

# %%
#Definindo, compilando e treinando nosso modelo
model = tf.keras.Sequential([
    keras.Input(shape=(1,)),
    keras.layers.Dense(units=1),
])

model.compile(optimizer="sgd", loss="mean_squared_error")
model.fit(xs,ys,epochs=300)
# Out:
# Epoch 1/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1985.5033
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6759
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4877
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3304
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1616
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2871
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2169
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9711
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9675
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9652
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1792
# Epoch 12/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8443
# Epoch 13/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7363
# Epoch 14/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7789
# Epoch 15/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5352
# Epoch 16/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6391
# Epoch 17/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4194
# Epoch 18/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3718
# Epoch 19/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2725
# Epoch 20/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2526
# Epoch 21/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2015
# Epoch 22/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1121
# Epoch 23/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1736
# Epoch 24/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1365
# Epoch 25/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0713
# Epoch 26/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0141
# Epoch 27/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0478
# Epoch 28/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8931
# Epoch 29/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9448
# Epoch 30/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8359
# Epoch 31/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8419
# Epoch 32/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7781
# Epoch 33/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8124
# Epoch 34/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7174
# Epoch 35/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7237
# Epoch 36/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7224
# Epoch 37/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6460
# Epoch 38/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6948
# Epoch 39/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6024
# Epoch 40/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5831
# Epoch 41/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6289
# Epoch 42/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5694
# Epoch 43/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4995
# Epoch 44/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5003
# Epoch 45/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4757
# Epoch 46/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4821
# Epoch 47/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4528
# Epoch 48/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4256
# Epoch 49/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5226
# Epoch 50/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4225
# Epoch 51/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3883
# Epoch 52/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3638
# Epoch 53/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3676
# Epoch 54/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3401
# Epoch 55/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3083
# Epoch 56/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3150
# Epoch 57/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3144
# Epoch 58/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2776
# Epoch 59/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2883
# Epoch 60/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2625
# Epoch 61/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2556
# Epoch 62/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2460
# Epoch 63/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2166
# Epoch 64/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2179
# Epoch 65/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2019
# Epoch 66/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2088
# Epoch 67/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1986
# Epoch 68/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1934
# Epoch 69/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1709
# Epoch 70/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1727
# Epoch 71/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1893
# Epoch 72/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1579
# Epoch 73/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1590
# Epoch 74/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1551
# Epoch 75/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1459
# Epoch 76/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1357
# Epoch 77/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1400
# Epoch 78/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1253
# Epoch 79/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1360
# Epoch 80/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1294
# Epoch 81/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1237
# Epoch 82/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1148
# Epoch 83/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1093
# Epoch 84/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1142
# Epoch 85/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1073
# Epoch 86/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1072
# Epoch 87/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0958
# Epoch 88/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0996
# Epoch 89/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0888
# Epoch 90/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0907
# Epoch 91/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0843
# Epoch 92/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0721
# Epoch 93/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0774
# Epoch 94/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0706
# Epoch 95/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0723
# Epoch 96/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0698
# Epoch 97/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0686
# Epoch 98/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0671
# Epoch 99/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0625
# Epoch 100/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0623
# Epoch 101/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0500
# Epoch 102/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0513
# Epoch 103/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0496
# Epoch 104/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0438
# Epoch 105/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0473
# Epoch 106/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0452
# Epoch 107/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0413
# Epoch 108/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0397
# Epoch 109/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0404
# Epoch 110/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0379
# Epoch 111/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0358
# Epoch 112/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0339
# Epoch 113/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0327
# Epoch 114/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0335
# Epoch 115/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0302
# Epoch 116/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0272
# Epoch 117/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0269
# Epoch 118/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0266
# Epoch 119/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0273
# Epoch 120/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0242
# Epoch 121/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0233
# Epoch 122/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0238
# Epoch 123/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208
# Epoch 124/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0216
# Epoch 125/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205
# Epoch 126/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0190
# Epoch 127/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0198
# Epoch 128/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0196
# Epoch 129/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0173
# Epoch 130/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0176
# Epoch 131/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0152
# Epoch 132/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0168
# Epoch 133/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0158
# Epoch 134/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0157
# Epoch 135/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143
# Epoch 136/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0130
# Epoch 137/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0135
# Epoch 138/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0126
# Epoch 139/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0117
# Epoch 140/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0109
# Epoch 141/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0105
# Epoch 142/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0111
# Epoch 143/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0104
# Epoch 144/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0106
# Epoch 145/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0103
# Epoch 146/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0099
# Epoch 147/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 148/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 149/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0088
# Epoch 150/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075
# Epoch 151/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073
# Epoch 152/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0070
# Epoch 153/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0067
# Epoch 154/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0062
# Epoch 155/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064
# Epoch 156/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066
# Epoch 157/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0054
# Epoch 158/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0059
# Epoch 159/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0060
# Epoch 160/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051
# Epoch 161/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051
# Epoch 162/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047
# Epoch 163/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047
# Epoch 164/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039
# Epoch 165/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043
# Epoch 166/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039
# Epoch 167/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038
# Epoch 168/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041
# Epoch 169/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035
# Epoch 170/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032
# Epoch 171/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032
# Epoch 172/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032
# Epoch 173/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029
# Epoch 174/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030
# Epoch 175/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026
# Epoch 176/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025
# Epoch 177/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024
# Epoch 178/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026
# Epoch 179/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025
# Epoch 180/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023
# Epoch 181/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020
# Epoch 182/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022
# Epoch 183/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020
# Epoch 184/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019
# Epoch 185/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021
# Epoch 186/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018
# Epoch 187/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016
# Epoch 188/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015
# Epoch 189/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 190/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015
# Epoch 191/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016
# Epoch 192/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013
# Epoch 193/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013
# Epoch 194/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 195/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011
# Epoch 196/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011
# Epoch 197/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 198/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 199/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010
# Epoch 200/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011
# Epoch 201/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010
# Epoch 202/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1441e-04
# Epoch 203/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.8423e-04
# Epoch 204/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1537e-04
# Epoch 205/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8322e-04
# Epoch 206/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3556e-04
# Epoch 207/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7529e-04
# Epoch 208/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5102e-04
# Epoch 209/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8308e-04
# Epoch 210/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6419e-04
# Epoch 211/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5769e-04
# Epoch 212/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6491e-04
# Epoch 213/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6345e-04
# Epoch 214/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5469e-04
# Epoch 215/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2361e-04
# Epoch 216/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5494e-04
# Epoch 217/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9644e-04
# Epoch 218/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4867e-04
# Epoch 219/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5707e-04
# Epoch 220/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3705e-04
# Epoch 221/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3790e-04
# Epoch 222/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6366e-04
# Epoch 223/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3127e-04
# Epoch 224/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8155e-04
# Epoch 225/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7040e-04
# Epoch 226/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5181e-04
# Epoch 227/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3451e-04
# Epoch 228/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3115e-04
# Epoch 229/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9108e-04
# Epoch 230/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0894e-04
# Epoch 231/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8811e-04
# Epoch 232/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7872e-04
# Epoch 233/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6890e-04
# Epoch 234/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5239e-04
# Epoch 235/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3809e-04
# Epoch 236/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4613e-04
# Epoch 237/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2759e-04
# Epoch 238/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1290e-04
# Epoch 239/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9406e-04
# Epoch 240/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0235e-04
# Epoch 241/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9924e-04
# Epoch 242/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9614e-04
# Epoch 243/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7103e-04
# Epoch 244/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7612e-04
# Epoch 245/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5978e-04
# Epoch 246/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6699e-04
# Epoch 247/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4154e-04
# Epoch 248/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5261e-04
# Epoch 249/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3611e-04
# Epoch 250/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3079e-04
# Epoch 251/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3076e-04
# Epoch 252/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2723e-04
# Epoch 253/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3295e-04
# Epoch 254/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1758e-04
# Epoch 255/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1167e-04
# Epoch 256/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0134e-04
# Epoch 257/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7724e-05
# Epoch 258/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0856e-05
# Epoch 259/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9785e-05
# Epoch 260/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5898e-05
# Epoch 261/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8879e-05
# Epoch 262/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6603e-05
# Epoch 263/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5763e-05
# Epoch 264/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3706e-05
# Epoch 265/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6630e-05
# Epoch 266/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7567e-05
# Epoch 267/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4836e-05
# Epoch 268/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0732e-05
# Epoch 269/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6384e-05
# Epoch 270/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9689e-05
# Epoch 271/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9102e-05
# Epoch 272/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7529e-05
# Epoch 273/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2366e-05
# Epoch 274/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4004e-05
# Epoch 275/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9386e-05
# Epoch 276/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3906e-05
# Epoch 277/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2492e-05
# Epoch 278/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2543e-05
# Epoch 279/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9540e-05
# Epoch 280/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0871e-05
# Epoch 281/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6321e-05
# Epoch 282/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8014e-05
# Epoch 283/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3903e-05
# Epoch 284/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2373e-05
# Epoch 285/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2668e-05
# Epoch 286/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9539e-05
# Epoch 287/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2889e-05
# Epoch 288/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8622e-05
# Epoch 289/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7208e-05
# Epoch 290/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7448e-05
# Epoch 291/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7019e-05
# Epoch 292/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5096e-05
# Epoch 293/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2995e-05
# Epoch 294/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1439e-05
# Epoch 295/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2428e-05
# Epoch 296/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9766e-05
# Epoch 297/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9169e-05
# Epoch 298/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0491e-05
# Epoch 299/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9567e-05
# Epoch 300/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6584e-05

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 1)                   │               2 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4 (20.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
#print("prediction: "+ str(model.predict([17]))+"      real value: " + str(f1(17))) # (cod.original) vai dar erro pq ele recebeu uma lista python [17] enquanto esperava um array
print("prediction: "+ str(model.predict(np.array([17])))+"      real value: " + str(f1(17)))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# prediction: [[175.0161]]      real value: 175

# %%
val = np.linspace(0,10,63)
model.evaluate(x=val, y=f1(val))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0452e-05
# 1.8275970433023758e-05

# %% [markdown]
# A função `evaluate` retorna o "custo" (loss) da avaliação, definido na compilação.  Nesse caso, o valor reportado é o erro quadrático médio (MSE).

# %% [markdown]
# ## Aprendendo uma função não linear

# %%
def f2(x):
    '''
    Funcao não linear a ser aprendida
    '''
    return (x**2 + x*3 + 4)/200

# %%
x = np.linspace(0,10,100)
y = f2(x)

# %% [markdown]
# # <font color='blue'>Questão 1 </font>
# Defina as camadas para esta rede neural e treine seu modelo, note que a saída unitária _não deve_ ter função de ativação (por que?).

# %% [markdown]
# resposta:

# %%
model = tf.keras.Sequential([
    keras.Input(shape=(1,)),  # Entrada com uma única variável (dimensão 1)
    keras.layers.Dense(10, activation="relu"), # Camada densa com 10 neurônios e ativação ReLU
    keras.layers.Dense(5, activation="relu"), # Camada densa com 5 neurônios e ativação ReLU
    keras.layers.Dense(1) # Saída unitária sem função de ativação
])

model.compile(optimizer="adam", loss="mean_squared_error") # Configura o otimizador e a função de perda
model.fit(x,y,epochs=400) # Treina o modelo com os dados x e y por 400 épocas
# Out:
# Epoch 1/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.5724
# Epoch 2/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2954
# Epoch 3/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.
400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6599e-04
# Epoch 345/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4522e-04
# Epoch 346/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4999e-04
# Epoch 347/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5451e-04
# Epoch 348/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1784e-04
# Epoch 349/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.1271e-04
# Epoch 350/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1176e-04
# Epoch 351/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1066e-04
# Epoch 352/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4276e-04
# Epoch 353/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1924e-04
# Epoch 354/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7012e-04
# Epoch 355/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2090e-04
# Epoch 356/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8705e-04
# Epoch 357/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6377e-04
# Epoch 358/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0079e-04
# Epoch 359/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2227e-04
# Epoch 360/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4513e-04
# Epoch 361/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2177e-04
# Epoch 362/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4317e-04
# Epoch 363/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4797e-04
# Epoch 364/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5246e-04
# Epoch 365/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0286e-04
# Epoch 366/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8589e-04
# Epoch 367/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3546e-04
# Epoch 368/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7455e-04
# Epoch 369/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9084e-04
# Epoch 370/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0325e-04
# Epoch 371/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7997e-04
# Epoch 372/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3791e-04
# Epoch 373/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3223e-04
# Epoch 374/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6596e-04
# Epoch 375/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2762e-04
# Epoch 376/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6664e-04
# Epoch 377/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0560e-04
# Epoch 378/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4070e-04
# Epoch 379/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3498e-04
# Epoch 380/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7888e-04
# Epoch 381/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1872e-04
# Epoch 382/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0242e-04
# Epoch 383/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1685e-04
# Epoch 384/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4214e-04
# Epoch 385/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7199e-04
# Epoch 386/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7287e-04
# Epoch 387/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6332e-04
# Epoch 388/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9776e-04
# Epoch 389/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2939e-04
# Epoch 390/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6416e-04
# Epoch 391/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3279e-04
# Epoch 392/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0528e-04
# Epoch 393/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8105e-04
# Epoch 394/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1352e-04
# Epoch 395/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8260e-04
# Epoch 396/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0533e-04
# Epoch 397/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4046e-04
# Epoch 398/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6452e-04
# Epoch 399/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4003e-04
# Epoch 400/400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1267e-04

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                      │ (None, 10)                  │              20 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 5)                   │              55 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               6 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 245 (984.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 164 (660.00 B)

# %%
x_val = np.linspace(0,10,63)
y_val = f2(x_val)

# %%
model.evaluate(x=x_val,y=y_val)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.1474e-04
# 0.000503687362652272

# %% [markdown]
# ____________________________
# # <font color='blue'>Questão 2 </font>
#
#
#
# O que acontece se você muda as funções de ativação? Teste algumas diferentes e descreva seus resultados, em especial a tangente hiperbólica

# %% [markdown]
# **<font color='red'> Sua resposta aqui </font>**

# %% [markdown]
# O que acontece se você mudar a função de otimização? Teste diferentes funções e descreva seus resultados, em especial as funções SDG e RMSprop

# %% [markdown]
# **<font color='red'> Sua resposta aqui </font>**

# %% [markdown]
# Volte a primeira parte desse notebook e troque a função de ativação da rede de uma camada (pérceptron) de sdg para adam, o que acontece?

# %% [markdown]
# **<font color='red'> Sua resposta aqui </font>**

# %% [markdown]
# A avaliação de performance que realizamos foi apenas para pontos contidos no mesmo intervalo que o conjunto de treino, ou seja, foi apenas uma interpolação. Sem alterar sua rede repita o teste realizando uma extrapolação, com pontos fora do intervalo [0;10] e descreva seus resultados. O que aconteceu com a performance?

# %%
# Seu código aqui

# %% [markdown]
# **<font color='red'> Sua resposta aqui </font>**

# %% [markdown]
# # Prevendo se vai chover na Austrália
#
# Os próximos exercícios são, em grande parte, uma tradução e adaptação para o português brasileiro do tutorial intitulado [Build Your First Neural Network with Pytorch](https://curiousily.com/posts/build-your-first-neural-network-with-pytorch/)
#  entretanto algumas adaptações foram realizadas, tanto no texto, quanto no código, em relação à versão original para utilizar a biblioteca TensorFlow.
#
# Aqui você aprenderá como implementar, treinar e utilizar uma Rede Neural *Feed-Foward* simples para uma tarefa de classificação binária.
#
# Para tal, utilizaremos o pacote [TensorFlow 2.0](www.tensorflow.org) que é, atualmente, uma das principais ferramentas para a implementação de modelos neurais viáveis.
#
# A tarefa que usaremos para fins de exemplo será a de prever se choverá ou não numa cidade australiana amanhã, utilizando dados meteorológicos mensurados na mesma cidade no dia de hoje. A redução dessa tarefa de previsão a uma classificação binária é, evidentemente, uma grande simplificação do problema real de previsão meteorológica, mas como veremos, ainda pode apresentar resultados interessantes, além do caráter didático.
#
#
#
# As informações que utilizaremos para treinar nosso modelo para a tarefa de previsão de chuvas estão contidas num conjunto que reúne dados meteorológicos de diversas cidades australianas. Esse conjunto de dados foi curado e disponibilizado através do [Kaggle](https://www.kaggle.com/jsphyg/weather-dataset-rattle-package) por [Joe Young](https://www.kaggle.com/jsphyg).

# %%
# !mkdir data

# %%
# Baixando os dados:
# !curl https://raw.githubusercontent.com/alan-barzilay/NLPortugues/master/Semana%2002/data/weatherAUS.csv --output 'data/weatherAUS.csv'

# %% [markdown]
# Os dados estão no formato `.csv` e, com eles em mãos, o primeiro passo é carregá-los em um *data-frame*, usando a função [`pd.read_csv()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) do *pandas*.
#
#
# Com os dados carregados, é possível averiguar que eles são constituídos por 142193 entradas, cada uma contando com 24 variáveis distintas. É possível notar, também, que existem entradas para as quais nem todas as variáveis estão  instanciadas. Além disso, nem todos os valores estão nos formatos que gostaríamos que estivessem para serem processados.
#
# Isso é normal. Dados reais são cheios de falhas e problemas, e exigem trabalho e entendimento para serem utilizados da maneira correta. Por isso, é necessário realizar um **pré-processamento** para adequar os dados, antes de os passarmos para o modelo.
#
# O primeiro passo é escolher quais das variáveis meteorológicas nos interessam. No nosso caso, queremos prever se choverá ou não amanhã, então `RainTomorrow` será nossa variável alvo. Para prevê-la usaremos as variáveis  `Rainfall`, `Humidity3pm`, `Pressure9am` e `RainToday`, que serão nossas *features*.
#
#
#
# Em seguida, iniciamos o pré-processamento, propriamente dito.
#
# As variáveis `RainToday` e `RainTomorrow` possuem dois valores possíveis, *Yes* e *No*. Adeque esses valores, convertendo-os para $1$ e $0$, respectivamente.
#
#
#
#
# A seguir, remova todas as entradas que não tenham instanciado os valores de todas as variáveis de interesse com a função [`dropna()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html), pois essas entradas são inúteis para treinar nosso modelo.
#
#
#
# Com os dados pré-processados, é possível, agora, plotar as distribuições das variáveis de interesse para poder entender melhor como essas distribuições funcionam. Esse tipo de trabalho é muito importante na implementação real de redes neurais, conhecer os dados é fundamental para tirar o maior proveito do seu modelo e entender verdadeiramente seus resultados.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dentre todas as distribuições das variáveis de interesse, a que mais nos concerne é a da variável alvo, `RainTomorrow`, representada na figura acima.
#
#
# Essa distribuição nos revela um grande desbalanço entre os dois valores possíveis dessa variável, que constituirão as duas classes do nosso problema de classificação. Esse é um dado importante, pois pode influenciar significativamente a capacidade preditiva do modelo treinado.
#
# Existem maneiras de se lidar com o desbalanceamento dos dados, mas nesse tutorial utilizaremos os dados dessa forma. Isso significa que o *baseline* para a performance do nosso modelo deve ser $78\%$, isso porque, se um modelo chutasse que amanhã não irá chover, todas as vezes, ele obteria uma performance dessa ordem e, como esperamos gerar um modelo mais "inteligente" que isso, esperamos também que a a nossa performance seja superior a essa.
#
# Todo o código referente a esse pré-processamento deve ser escrito pelo próprio aluno seguindo o esqueleto das funções presentes no notebook. Para agilizar a exploração dos dados nós já fornecemos a implementação da função `visualize_data()` que plota visualizações para as distribuições das variáveis de interesse.

# %%
def visualize_data(data):
    """Gera graficos das distribuicoes das features"""

    ibm_pltt = ['#648FFF', '#785EF0', '#DC267F',
                '#FE6100', '#FFB000']  # Paleta colorblind-friendly

    # RainToday:
    sns.set()
    sns.set_palette(sns.color_palette([ibm_pltt[2], ibm_pltt[0]]))
    sns.countplot(x=data.RainToday)
    plt.xlabel('Choveu Hoje?')
    plt.ylabel('Contagem')
    plt.title("Valores de 'RainToday' para os dados pré-processados")
    plt.show()

    # RainTomorrow:
    sns.set()
    sns.set_palette(sns.color_palette([ibm_pltt[3], ibm_pltt[1]]))
    sns.countplot(x=data.RainTomorrow)
    plt.xlabel('Choverá Amanhã?')
    plt.ylabel('Contagem')
    plt.title("Valores de 'RainTomorrow' para os dados pré-processados")
    plt.show()

    # Humidity3pm:
    sns.set()
    sns.displot(data.Humidity3pm, color=ibm_pltt[0], stat='density', kde=True)
    plt.xlabel('Umidade às 3PM')
    plt.ylabel('Densidade normalizada')
    plt.title("Distribuição da variável 'Humidity3pm' para os dados pré-processados")
    plt.show()

    # Pressure9am:
    sns.set()
    sns.displot(data.Pressure9am, color=ibm_pltt[4], stat='density', kde=True)
    plt.xlabel('Pressão atmosférica às 9AM')
    plt.ylabel('Densidade normalizada')
    plt.title("Distribuição da variável 'Pressure9amm' para os dados pré-processados")
    plt.show()

    # Rainfall:
    sns.set()
    sns.histplot(data.Rainfall, color=ibm_pltt[1], bins=500, kde=False)
    plt.xlim(0, 10)
    plt.xlabel('Pluviosidade')
    plt.ylabel('Densidade normalizada')
    plt.title("Distribuição da variável 'Rainfall' para os dados pré-processados")
    plt.show()

    return

# %% [markdown]
# ## Pré processamento dos dados
# Já definimos uma função basica para lhe ajudar a explorar os dados, você precisará escrever uma função para carregar os dados, uma de pré-processamento e outra para fazer a separação em teste e treino.

# %% [markdown]
# # <font color='blue'>Questão 3 </font>
# Complete as funções aqui descritas seguindo a assinatura sugerida
#
# Para separar em treino e teste, de uma olhada na função [train_test_split()](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) do Scikit-Learn

# %%
def load_data(data_path='data/weatherAUS.csv')-> pd.DataFrame:
    """Funcao que importa dados de um arquivo csv, usando pandas"""
    #Seu código aqui

    return raw_data

def pre_processing(raw_data:pd.DataFrame)-> pd.DataFrame:
    """Funcao que filtra e limpa os dados meteorologicos para o treinamento"""
    #Seu código aqui

    return processed_data


def split_data(data:pd.DataFrame, val_size= 0.2)-> np.array:
    """Funcao que separa seus dados em teste e treino conforme a proporcao val_size"""
    #Seu código aqui

    return x_train, x_val, y_train, y_val

# %%
df = load_data()
df = pre_processing(df)
visualize_data(df)
x_train, x_val, y_train, y_val = split_data(df,)

# %% [markdown]
# # <font color='blue'>Questão 4 </font>
# Agora que você ja ganhou uma familiaridade com a API Keras, escreva sozinho do começo ao fim um modelo que ira dizer se amanhã vai chover ou não e avalie sua performance.

# %%
# Seu código aqui
